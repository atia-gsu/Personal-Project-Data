# %%
import pandas as pd

# %%
data = pd.read_csv (r"C:\Users\fisul\Desktop\python-projects\Netflix Dataset.csv")

# %%
# display DS
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N     New_RD  \
# 0  In a future where the elite inhabit an island ... 2020-08-14 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23 2016-12-23
#
#   Release_Date_Clean    Year Minutes     Unit
# 0    August 14, 2020  2020.0       4  Seasons
# ...

# %%
# display top 5
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# bottom 5 
data.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
# no of rows & columns
data.shape
# Out:
# (7789, 11)

# %%
# total values in DS
data.size
# Out:
# 85657

# %%
# columns name
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7787 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   Release_Date  7777 non-null   object
#  7   Rating        7780 non-null   object
#  8   Duration      7787 non-null   object
#  9   Type          7787 non-null   object
#  10  Description   7787 non-null   object
# dtypes: object(11)
# memory usage: 730.0+ KB

# %% [markdown]
# # Find Duplicate records

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7787, dtype: bool

# %%
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %% [markdown]
# # delete duplicates temporarily

# %%
data.drop_duplicates()
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
# checking duplicates again
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# # Delete duplicates parmanently

# %%
data.drop_duplicates(inplace = True)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
data.shape
# Out:
# (7787, 11)

# %% [markdown]
# # checking null records in boolean format

# %%
data.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
data.isnull().sum()  # show the count of null values in each columns
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# # showing null values using heat-map (by importing seaborn library)

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
# For House of Cards, what is the Show ID and who is the director?

# %%
data[data['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
data['Title'].str.contains('House of Cards')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Name: Title, Length: 7787, dtype: bool

# %%
data[data['Title'].isin(['Backfire'])]
# Out:
#     Show_Id Category     Title     Director  \
# 683    s684    Movie  Backfire  Dave Patten
#
#                                                   Cast        Country  \
# 683  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
#
#       Release_Date Rating Duration                                   Type  \
# 683  April 5, 2019  TV-MA   97 min  Dramas, Independent Movies, Thrillers
#
#                                            Description
# 683  When two would-be robbers accidentally kill a ...

# %%
data[data['Director'].isin(['Dave Patten'])]
# Out:
#     Show_Id Category     Title     Director  \
# 683    s684    Movie  Backfire  Dave Patten
#
#                                                   Cast        Country  \
# 683  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
#
#       Release_Date Rating Duration                                   Type  \
# 683  April 5, 2019  TV-MA   97 min  Dramas, Independent Movies, Thrillers
#
#                                            Description
# 683  When two would-be robbers accidentally kill a ...

# %%
data[data['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# # in which year highest no of TV shows and movies were released? show with bar graph?

# %%
# for this we need to know data type of Release_date
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
#pd.set_option('display.max_rows', None) #displaying full dataset

# %%
data.head(10)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
# 6      s7    Movie    122    Yasir Al Yasiri
# 7      s8    Movie    187     Kevin Reynolds
# 8      s9    Movie    706      Shravan Kumar
# 9     s10    Movie   1920       Vikram Bhatt
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %%
data['Release_Date_Clean'] = data['Release_Date'].str.strip()

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N     New_RD  \
# 0  In a future where the elite inhabit an island ... 2020-08-14 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23 2016-12-23
#
#   Release_Date_Clean    Year
# 0    August 14, 2020  2020.0
# 1  December 23, 2016  2016.0

# %%
# creating new column using to_datetime
data['Date_N'] = pd.to_datetime(data['Release_Date_Clean'])

# %%
data.isnull().sum()
# Out:
# Show_Id                  0
# Category                 0
# Title                    0
# Director              2388
# Cast                   718
# Country                507
# Release_Date            10
# Rating                   7
# Duration                 0
# Type                     0
# Description              0
# Date_N                  10
# New_RD                  98
# Release_Date_Clean      10
# dtype: int64

# %%
# Check the first 10 unique, non-missing values in the 'Release_Date' column
print(data['Release_Date'].dropna().unique()[780:787])
# Out:
# ['July 28, 2017' 'August 26, 2019' 'October 4, 2020' 'August 5, 2016'
#  'December 11, 2017' 'March 23, 2018' 'October 24, 2019']

# %%
# The format string %B %d, %Y matches 'July 28, 2017'
data['New_RD'] = pd.to_datetime(data['Release_Date'], format='%B %d, %Y', errors='coerce')

# %%
data.isnull().sum()
# Out:
# Show_Id                  0
# Category                 0
# Title                    0
# Director              2388
# Cast                   718
# Country                507
# Release_Date            10
# Rating                   7
# Duration                 0
# Type                     0
# Description              0
# Date_N                  10
# New_RD                  98
# Release_Date_Clean      10
# dtype: int64

# %%
data.dtypes
# Out:
# Show_Id                       object
# Category                      object
# Title                         object
# Director                      object
# Cast                          object
# Country                       object
# Release_Date                  object
# Rating                        object
# Duration                      object
# Type                          object
# Description                   object
# Date_N                datetime64[ns]
# New_RD                datetime64[ns]
# Release_Date_Clean            object
# dtype: object

# %%
# dt.year.value_counts()
data['Date_N'].dt.year.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # dt.year.value_counts()
# ----> 2 data['Date_N'].dt.year.value_counts().head(5)
#
# NameError: name 'data' is not defined

# %%
# Bar graph
data['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Date_N'>

# %% [markdown]
# # How many movies and TV shows are in the DS? Show with bar graph

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N     New_RD  \
# 0  In a future where the elite inhabit an island ... 2020-08-14 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23 2016-12-23
#
#   Release_Date_Clean
# 0    August 14, 2020
# 1  December 23, 2016

# %%
data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5379
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(data['Category'])
# Out:
# <Axes: xlabel='count', ylabel='Category'>

# %%
sns.countplot(x='Category', data=data)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# # show all movies that were released in 2020

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N     New_RD  \
# 0  In a future where the elite inhabit an island ... 2020-08-14 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23 2016-12-23
#
#   Release_Date_Clean
# 0    August 14, 2020
# 1  December 23, 2016

# %%
#creating new column
data['Year'] = data['Date_N'].dt.year

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N     New_RD  \
# 0  In a future where the elite inhabit an island ... 2020-08-14 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23 2016-12-23
#
#   Release_Date_Clean    Year
# 0    August 14, 2020  2020.0
# 1  December 23, 2016  2016.0

# %%
# Filtering according to conditions
data[(data['Category'] == 'Movie') & (data['Year'] == 2020)].head()
# Out:
#    Show_Id Category                          Title  \
# 4       s5    Movie                             21
# 6       s7    Movie                            122
# 14     s15    Movie                           3022
# 27     s28    Movie                         #Alive
# 28     s29    Movie  #AnneFrank - Parallel Stories
#
#                        Director  \
# 4                Robert Luketic
# 6               Yasir Al Yasiri
# 14                   John Suits
# 27                       Cho Il
# 28  Sabina Fedeli, Anna Migotto
#
#                                                  Cast        Country  \
# 4   Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 6   Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
# 14  Omar Epps, Kate Walsh, Miranda Cosgrove, Angus...  United States
# 27                           Yoo Ah-in, Park Shin-hye    South Korea
# 28                        Helen Mirren, Gengher Gatti          Italy
#
# ...

# %%
data[(data['Category'] == 'TV Show') & (data['Year'] == 2018)].head(10)
# Out:
#     Show_Id Category                             Title       Director  \
# 11      s12  TV Show                              1983            NaN
# 86      s87  TV Show      21 Sarfarosh: Saragarhi 1897            NaN
# 87      s88  TV Show                        21 Thunder            NaN
# 134    s135  TV Show                        7 Days Out            NaN
# 138    s139  TV Show        72 Dangerous Animals: Asia            NaN
# 197    s198  TV Show  A Little Help with Carol Burnett            NaN
# 248    s249  TV Show             A Very Secret Service            NaN
# 260    s261  TV Show                          A.I.C.O.  Kazuya Murata
# 294    s295  TV Show              Accidentally in Love            NaN
# 306    s307  TV Show             Adam Ruins Everything            NaN
#
#                                                   Cast                Country  \
# 11   Robert Więckiewicz, Maciej Musiał, Michalina O...  Poland, United States
# ...

# %%
data[(data['Category'] == 'TV Show') & (data['Country'] == 'Japan')].head() # TV show released in Japan
# Out:
#     Show_Id Category                                Title       Director  \
# 24      s25  TV Show  ​SAINT SEIYA: Knights of the Zodiac            NaN
# 260    s261  TV Show                             A.I.C.O.  Kazuya Murata
# 341    s342  TV Show                           Aggretsuko            NaN
# 348    s349  TV Show   Ainori Love Wagon: African Journey            NaN
# 349    s350  TV Show     Ainori Love Wagon: Asian Journey            NaN
#
#                                                   Cast Country  \
# 24   Bryson Baugus, Emily Neves, Blake Shepard, Pat...   Japan
# 260  Haruka Shiraishi, Yusuke Kobayashi, Makoto Fur...   Japan
# 341  Kaolip, Komegumi Koiwasaki, Maki Tsuruta, Soht...   Japan
# 348     Becky, Ryo Kato, Karina Maruyama, Kohei Takeda   Japan
# 349       Becky, Audrey, Mayuko Kawakita, Shimon Okura   Japan
#
#          Release_Date Rating   Duration  \
# 24   January 23, 2020  TV-14  2 Seasons
# 260     March 9, 2018  TV-14   1 Season
# ...

# %%
data[(data['Category'] == 'TV Show') & (data['Country'] == 'Japan')]['Title']
# Out:
# 24                    ​SAINT SEIYA: Knights of the Zodiac
# 260                                              A.I.C.O.
# 341                                            Aggretsuko
# 348                    Ainori Love Wagon: African Journey
# 349                      Ainori Love Wagon: Asian Journey
# 360                                      AJIN: Demi-Human
# 363                                        Akame ga Kill!
# 393                                   Alice in Borderland
# 516                                          Angel Beats!
# 540                   Anohana: The Flower We Saw That Day
# 556                                              忍者ハットリくん
# 569                               ARASHI's Diary -Voyage-
# 610                                               Atelier
# 616                                       Attack on Titan
# 651                                      B: The Beginning
# 676                          Back Street Girls -GOKUDOLS-
# ...

# %% [markdown]
# # show top 10 Directors, who gave the highest number of TV shows & Movies to Netflix?

# %%
data['Director'].value_counts().head(15)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Martin Scorsese           12
# Jay Chapman               12
# Steven Spielberg          10
# David Dhawan               9
# Ryan Polito                8
# Lance Bangs                8
# Robert Rodriguez           8
# Quentin Tarantino          8
# Johnnie To                 8
# Shannon Hartman            8
# Name: count, dtype: int64

# %%
data['Director'].value_counts().head(15)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Martin Scorsese           12
# Jay Chapman               12
# Steven Spielberg          10
# David Dhawan               9
# Ryan Polito                8
# Lance Bangs                8
# Robert Rodriguez           8
# Quentin Tarantino          8
# Johnnie To                 8
# Shannon Hartman            8
# Name: count, dtype: int64

# %% [markdown]
# # Show all the Records, where Movie Category is Comedies or Country is UK

# %%
# Filterning (and, or operations)
data[(data['Category'] == 'Movie') & (data['Type'] =='Comedies')].head(15) # comedies only
# Out:
#     Show_Id Category                                        Title  \
# 33      s34    Movie                                 #realityhigh
# 72      s73    Movie                                     17 Again
# 84      s85    Movie                                    21 & Over
# 148    s149    Movie                         A Bad Moms Christmas
# 174    s175    Movie                  A Futile and Stupid Gesture
# 240    s241    Movie                             A Thousand Words
# 317    s318    Movie                  Adventures in Public School
# 472    s473    Movie                 American Pie 9: Girls' Rules
# 522    s523    Movie                             Anger Management
# 626    s627    Movie  Austin Powers: International Man of Mystery
# 692    s693    Movie                               Bad Grandpa .5
# 795    s796    Movie                                  Bebe's Kids
# 864    s865    Movie                 Between Two Ferns: The Movie
# ...

# %%
data[(data['Category'] == 'Movie') & (data['Type'] =='Comedies') | (data['Country'] == 'United Kingdom')].head(3)
# Out:
#    Show_Id Category         Title          Director  \
# 19     s20    Movie           '89               NaN
# 33     s34    Movie  #realityhigh  Fernando Lebrija
# 58     s59  TV Show   100% Hotter               NaN
#
#                                                  Cast         Country  \
# 19                 Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# 33  Nesta Cooper, Kate Walsh, John Michael Higgins...   United States
# 58  Daniel Palmer, Melissa Sophia, Karen Williams,...  United Kingdom
#
#          Release_Date Rating  Duration  \
# 19       May 16, 2018  TV-PG    87 min
# 33  September 8, 2017  TV-14    99 min
# 58   November 1, 2019  TV-14  1 Season
#
#                                                  Type  \
# 19                                      Sports Movies
# 33                                           Comedies
# 58  British TV Shows, International TV Shows, Real...
#
#                                           Description     Date_N     New_RD  \
# ...

# %% [markdown]
# # In how many moies/shows, Tom Cruise was cast?

# %%
# filtering 
data[data['Cast'] == 'Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, New_RD, Release_Date_Clean, Year]
# Index: []

# %%
# str.contains()
data[data['Cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[125], line 2
#       1 # str.contains()
# ----> 2 data[data['Cast'].str.contains('Tom Cruise')]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4092, in DataFrame.__getitem__(self, key)
#    4089     return self.where(key)
#    4091 # Do we have a (boolean) 1d indexer?
# -> 4092 if com.is_bool_indexer(key):
#    4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\anaconda3\Lib\site-packages\pandas\core\common.py:136, in is_bool_indexer(key)
#     132     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133     if lib.is_bool_array(key_array, skipna=True):
#     134         # Don't raise on e.g. ["A", "B", np.nan], see
# ...

# %% [markdown]
# # Creating new data-frame

# %%
data_new = data.dropna()                 # it drops the rows that contains all or any missing values

# %%
data_new.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description     Date_N     New_RD  \
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23 2016-12-23
# 2  When an army recruit is found dead, his fellow... 2018-12-20 2018-12-20
#
#   Release_Date_Clean    Year
# 1  December 23, 2016  2016.0
# 2  December 20, 2018  2018.0

# %%
data_new[data_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_N     New_RD  \
# 3860  Through chance, human action, past history and... 2020-01-01 2020-01-01
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01 2019-07-01
#
#      Release_Date_Clean    Year
# 3860    January 1, 2020  2020.0
# 5071       July 1, 2019  2019.0

# %%
# What are the different Ratings defined by Netflix ?
data['Rating'].nunique()
# Out:
# 14

# %%
# data.Rating.unique()

data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
# How many Movies got the 'TV-14' rating, in Canada ?
data[(data['Category']=='Movie') & (data['Rating']=='TV-14')].shape  # all countries
# Out:
# (1272, 17)

# %%
data[(data['Category']=='Movie') & (data['Rating']=='TV-14') & (data['Country']=='Canada')].shape  # Canada only
# Out:
# (11, 15)

# %%
# How many TV Show got the 'R' rating, after year 2018 ?

data[(data['Category']=='TV Show') & (data['Rating']=='R')]  # For all years
# Out:
#      Show_Id Category                                Title           Director  \
# 4497   s4498  TV Show                                Nobel                NaN
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 4497  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#            Release_Date Rating  Duration  \
# 4497  December 10, 2016      R  1 Season
# 6437     April 25, 2019      R  1 Season
#
#                                                  Type  \
# 4497  International TV Shows, TV Dramas, TV Thrillers
# 6437                                         TV Shows
#
#                                             Description     Date_N     New_RD  \
# 4497  A series of incidents in Afghanistan set compl... 2016-12-10 2016-12-10
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25 2019-04-25
#
# ...

# %%
data[(data['Category']=='TV Show') & (data['Rating']=='R') & (data['Year'] > 2018)]  # after year 2018 ?
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date Rating  Duration      Type  \
# 6437  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description     Date_N     New_RD  \
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25 2019-04-25
#
#      Release_Date_Clean    Year Minutes    Unit
# 6437     April 25, 2019  2019.0       1  Season

# %%
# What is the maximum duration of a Movie/TV-Show on Netflix ?

data.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
# data.Duration.dtypes

data.Duration.dtypes
# Out:
# dtype('O')

# %%
# str.split()

data[['Minutes', 'Unit']] = data['Duration'].str.split(' ', expand = True)

# %%
data.head(4)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# ...

# %%
# data.Minutes.max()

data['Minutes'].max()
# Out:
# '99'

# %%
data['Minutes'].min()
# Out:
# '1'

# %% [markdown]
# # Which individual country has the Highest No. of TV Shows ?

# %%
data_tvshow = data[data['Category'] == 'TV Show']   # creating new data frame with TV show only

# %%
data_tvshow.Country.value_counts().head(20)       # counting for all contries
# Out:
# Country
# United States            705
# United Kingdom           204
# Japan                    157
# South Korea              147
# India                     71
# Taiwan                    68
# Canada                    59
# Australia                 46
# France                    46
# Spain                     45
# China                     36
# Mexico                    35
# Turkey                    27
# Brazil                    26
# United States, Canada     22
# Thailand                  22
# Colombia                  20
# Germany                   19
# Singapore                 17
# Argentina                 16
# Name: count, dtype: int64

# %%
data_tvshow.Country.value_counts().head(1)   # An individual country which has the Highest No. of TV Shows
# Out:
# Country
# United States    705
# Name: count, dtype: int64

# %% [markdown]
# # How can we sort the dataset by Year ?

# %%
data.sort_values(by='Year').head(10)   # by default Decending order
# Out:
#      Show_Id Category                                       Title  \
# 1765   s1766  TV Show                             Dinner for Five
# 7115   s7114    Movie                        To and From New York
# 5766   s5766    Movie                                    Splatter
# 3248   s3249    Movie                     Just Another Love Story
# 3840   s3841    Movie                 Mad Ron's Prevues from Hell
# 7151   s7150    Movie                          Too Young the Hero
# 7232   s7231    Movie                        Triumph of the Heart
# 6847   s6846    Movie                        The Ryan White Story
# 5042   s5042    Movie  Quiet Victory: The Charlie Wedemeyer Story
# 308     s309    Movie                    Adam: His Song Continues
#
#                   Director                                               Cast  \
# 1765                   NaN                                                NaN
# 7115  Sorin Dan Mihalcescu  Barbara King, Shaana Diya, John Krisiukenas, Y...
# ...

# %%
data.sort_values(by = 'Year', ascending = False).head(10)     # for ascending
# Out:
#      Show_Id Category                                       Title  \
# 6204   s6204  TV Show  The Cat in the Hat Knows a Lot About That!
# 692     s693    Movie                              Bad Grandpa .5
# 1041   s1042    Movie                            Bonnie and Clyde
# 560     s561    Movie                                    Apaharan
# 7553   s7552    Movie                   What Happened to Mr. Cha?
# 72       s73    Movie                                    17 Again
# 5521   s5521    Movie                          Sex and the City 2
# 5522   s5522    Movie                 Sex and the City: The Movie
# 366     s367    Movie                                   Al acecho
# 5955   s5955    Movie                            Taare Zameen Par
#
#                   Director                                               Cast  \
# 6204      Tony Collingwood  Martin Short, Alexa Torrington, Jacob Ewaniuk,...
# 692          Jeff Tremaine  Johnny Knoxville, Jackson Nicoll, Greg Harris,...
# ...

# %% [markdown]
# # Find all the instances where :
# Category is 'Movie' and Type is 'Dramas'
#
# or
#
# Category is 'TV Show' & Type is 'Kids' TV'

# %%
# Category is 'Movie' and Type is 'Dramas'
data [ (data['Category']=='Movie') & (data['Type']=='Dramas') ].head(2)
# Out:
#   Show_Id Category Title        Director  \
# 4      s5    Movie    21  Robert Luketic
# 7      s8    Movie   187  Kevin Reynolds
#
#                                                 Cast        Country  \
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 7  Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
#
#        Release_Date Rating Duration    Type  \
# 4   January 1, 2020  PG-13  123 min  Dramas
# 7  November 1, 2019      R  119 min  Dramas
#
#                                          Description     Date_N     New_RD  \
# 4  A brilliant group of students become card-coun... 2020-01-01 2020-01-01
# 7  After one of his high school students attacks ... 2019-11-01 2019-11-01
#
#   Release_Date_Clean    Year Minutes Unit
# 4    January 1, 2020  2020.0     123  min
# 7   November 1, 2019  2019.0     119  min

# %%
# Category is 'TV Show' & Type is 'Kids' TV'
data [ (data['Category']=='TV Show') & (data['Type']== "Kids' TV") ].head(2)
# Out:
#     Show_Id Category         Title     Director  \
# 111    s112  TV Show       44 Cats          NaN
# 276    s277  TV Show  Abby Hatcher  Kyran Kelly
#
#                                                   Cast                Country  \
# 111  Sarah Natochenny, Suzy Myers, Simona Berman, E...                  Italy
# 276  Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...  United States, Canada
#
#         Release_Date Rating   Duration      Type  \
# 111  October 1, 2020  TV-Y7  2 Seasons  Kids' TV
# 276     July 1, 2020   TV-Y   1 Season  Kids' TV
#
#                                            Description     Date_N     New_RD  \
# 111  Paw-esome tales abound when singing furry frie... 2020-10-01 2020-10-01
# 276  A big-hearted girl helps her Fuzzly friends wh... 2020-07-01 2020-07-01
#
#     Release_Date_Clean    Year Minutes     Unit
# 111    October 1, 2020  2020.0       2  Seasons
# 276       July 1, 2020  2020.0       1   Season

# %% [markdown]
# # Final- both conditions with or operation:
# Category is 'Movie' and Type is 'Dramas'
#
# or
#
# Category is 'TV Show' & Type is 'Kids' TV'

# %%
data [ (data['Category']=='Movie') & (data['Type']=='Dramas') | (data['Category']=='TV Show') & (data['Type']== "Kids' TV") ].head()
# Out:
#     Show_Id Category                       Title        Director  \
# 4        s5    Movie                          21  Robert Luketic
# 7        s8    Movie                         187  Kevin Reynolds
# 111    s112  TV Show                     44 Cats             NaN
# 170    s171    Movie                A Family Man   Mark Williams
# 232    s233    Movie  A Stoning in Fulham County   Larry Elikann
#
#                                                   Cast                Country  \
# 4    Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...          United States
# 7    Samuel L. Jackson, John Heard, Kelly Rowan, Cl...          United States
# 111  Sarah Natochenny, Suzy Myers, Simona Berman, E...                  Italy
# 170  Gerard Butler, Gretchen Mol, Alison Brie, Will...  Canada, United States
# 232  Ken Olin, Jill Eikenberry, Maureen Mueller, Gr...          United States
#
#           Release_Date Rating   Duration      Type  \
# ...
